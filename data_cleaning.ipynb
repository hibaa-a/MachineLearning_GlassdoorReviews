# %%
#importing library
import pandas as pd

# %%
# Creating a reference to the CSV files
data_csv = "Resources/glassdoor_reviews.csv"
data_csv = pd.read_csv(data_csv)

# %%
data_csv
# Out:
#                          firm date_review                         job_title  \
# 0       AFH-Wealth-Management  2015-04-05
# 1       AFH-Wealth-Management  2015-12-11              Office Administrator
# 2       AFH-Wealth-Management  2016-01-28              Office Administrator
# 3       AFH-Wealth-Management  2016-04-16
# 4       AFH-Wealth-Management  2016-04-23              Office Administrator
# ...                       ...         ...                               ...
# 838561         the-LEGO-Group  2021-06-02                 Marketing Manager
# 838562         the-LEGO-Group  2021-06-03                   Sales Associate
# 838563         the-LEGO-Group  2021-06-03                        Strategist
# 838564         the-LEGO-Group  2021-06-04   Customer Service Representative
# 838565         the-LEGO-Group  2021-06-04        Human Resources Specialist
#
#                                     current  \
# 0                          Current Employee
# ...

# %%
data_csv=data_csv.dropna()
data_csv
# Out:
#                          firm date_review  \
# 50      AFH-Wealth-Management  2020-10-01
# 51      AFH-Wealth-Management  2021-02-05
# 52      AFH-Wealth-Management  2021-02-07
# 53      AFH-Wealth-Management  2021-02-07
# 60      AFH-Wealth-Management  2021-05-12
# ...                       ...         ...
# 838556         the-LEGO-Group  2021-05-21
# 838558         the-LEGO-Group  2021-05-25
# 838560         the-LEGO-Group  2021-05-31
# 838561         the-LEGO-Group  2021-06-02
# 838565         the-LEGO-Group  2021-06-04
#
#                                   job_title  \
# 50                     Office Administrator
# 51                          Quality Control
# 52                        IFA Administrator
# 53                    Investment Operations
# 60              Client Engagement Executive
# ...                                     ...
# 838556   Sales Associate (Brick Specialist)
# 838558               Senior Product Manager
# 838560           Senior Experience Designer
# ...

# %%
data_csv.to_csv('Resources/glassdoor_reviews_clean.csv')
